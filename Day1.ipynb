# %% [markdown]
# <a href="https://colab.research.google.com/github/RobAltena/AdventOfCode2025/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

data = """L68
L30
R48
L5
R60
L55
L1
L99
R14
L82
"""

data = requests.get('https://raw.githubusercontent.com/RobAltena/AdventofCode2025/refs/heads/main/advent_day1_input.txt').text
deltas = list((int(i[1:]) if i.startswith('R') else -int(i[1:]) for i in data.split()))

# %%
pos = 50
counter_part1 = 0
counter_part2 = 0
for delta in deltas:
  for i in range(abs(delta)):
    pos += 1 if delta > 0 else -1
    if pos == -1: pos = 99
    if pos == 100: pos = 0

    if pos == 0: counter_part2 +=1


  if pos == 0: counter_part1 +=1

print(f'Day 1, part 1: {counter_part1}')
print(f'Day 1, part 2: {counter_part2}')
